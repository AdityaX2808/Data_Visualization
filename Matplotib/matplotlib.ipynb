# %% [markdown]
# <h1> Matplotlib.pyplot Problems</h1>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Write a Python program to draw a line with suitable label in the x axis, y axis and a title

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y,label='y=2x',color='blue')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Simple line plot')
plt.legend()
plt.show()

# %% [markdown]
# 2. Write a Python program to draw a line using given axis values with suitable label in the x axis, y axis and a title.

# %%
x = [10,20,30,40,50]
y = [5,15,25,35,45]
plt.plot(x,y,label='Given Data',color='red')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line plot with given axis values')
plt.legend()
plt.show()

# %% [markdown]
# 3. Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.
# Test Data:
# test.txt
# 1 2
# 2 4
# 3 1

# %%
x = []
y = []
with open('test.txt','r') as file:
    for line in file:
        data = line.split()
        x.append(int(data[0]))
        y.append(int(data[1]))
plt.plot(x,y,label='Data from file',color='green')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line plot from file data')
plt.legend()
plt.show()

# %% [markdown]
# 4. Write a Python program to draw line charts of the financial data of Alphabet Inc. between
# October 3, 2016 to October 7, 2016.
# Sample Financial data (fdata.csv):
# Date,Open,High,Low,Close
# 03-10-16,774.25,776.065002,769.5,772.559998
# 04-10-16,776.030029,778.710022,772.890015,776.429993
# 05-10-16,779.309998,782.070007,775.650024,776.469971
# 06-10-16,779,780.47998,775.539978,776.859985
# 07-10-16,779.659973,779.659973,770.75,775.080017

# %%
import csv
dates = []
closing_prices = []
with open('fdata.csv','r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        dates.append(row[0])
        closing_prices.append(float(row[4]))
    plt.plot(dates,closing_prices,marker='o',linestyle='-',color = 'blue')
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.title('Alphabet Inc. Financial Data')
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()
# Out:
# C:\Users\Aditya\AppData\Local\Temp\ipykernel_20284\328359391.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# 5. Write a Python program to plot two or more lines on same plot with suitable legends of each line.

# %%
x = [1,2,3,4,5]
y1 = [2,4,6,8,10]
y2 = [1,3,5,7,9]
plt.plot(x,y1,marker='o',linestyle='-',color='blue',label='Line 1')
plt.plot(x,y2,marker='x',linestyle='--',color='red',label='Line 2')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple line plots')
plt.legend()
plt.show()

# %% [markdown]
# 6. Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
x = [1,2,3,4,5]
y1 = [2,4,6,8,10]
y2 = [1,3,5,7,9]
plt.plot(x,y1,marker='o',linestyle='-',color='blue',linewidth=2,label='Line 1')
plt.plot(x,y2,marker='x',linestyle='--',color='red',linewidth=3,label='Line 2')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Customized line plots')
plt.legend()
plt.show()

# %% [markdown]
# 7. Write a Python program to plot two or more lines with different styles

# %%
x = [1,2,3,4,5]
y1 = [2,4,6,8,10]
y2 = [1,3,5,7,9]
plt.plot(x,y1,marker='o',linestyle='-',color='blue',linewidth=2,label='Line 1')
plt.plot(x,y2,marker='x',linestyle='--',color='red',linewidth=3,label='Line 2')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple line plots with different styles')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# 8. Write a Python program to plot two or more lines and set the line markers.

# %%
x = [1,2,3,4,5]
y1 = [2,4,6,8,10]
y2 = [1,3,5,7,9]
plt.plot(x,y1,marker='o',linestyle='-',color='blue',label='Line 1')
plt.plot(x,y2,marker='x',linestyle='--',color='red',label='Line 2')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple line plots with different line markers')
plt.legend()
plt.show()

# %% [markdown]
# 9. Write a Python program to display the current axis limits values and set new axis values

# %%
import numpy as np
x = np.linspace(0,10,100)
y = np.sin(x)
plt.plot(x,y)
print("Current X-Axis limits:",plt.xlim())
print("Current Y-Axis limits:",plt.ylim())
plt.xlim([2,8])
plt.ylim([-1.5,1.5])
plt.show()
# Out:
# Current X-Axis limits: (-0.5, 10.5)
# Current Y-Axis limits: (-1.0993384025373631, 1.0996461858110391)

# %% [markdown]
# 10. Write a Python program to plot quantities which have an x and y position.

# %%
x = [1,2,3,4,5]
y = [10,20,25,30,50]
plt.scatter(x,y,color='blue',marker='o',label='Data Points')
plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %% [markdown]
# 11. Write a Python program to plot several lines with different format styles in one command using arrays.

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y1 = np.array([10,20,25,30,50])
y2 = np.array([5,15,20,25,35])
y3 = np.array([2,8,18,28,40])
plt.plot(x,y1,'bo-',x,y2,'rx--',x,y3,'gD:')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Multiple lines with different style')
plt.show()

# %% [markdown]
# 12. Write a Python program to create multiple types of charts

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y1 = np.array([10,20,25,30,50])
y2 = np.array([5,15,20,25,35])
fig,axs = plt.subplots(2,2,figsize=(10,10))
axs[0,0].plot(x,y1,'bo-',label='Line 1')
axs[0,0].set_title('Line Chart')
axs[0,0].legend()
axs[0,1].bar(x,y1,color='green',label='Bars')
axs[0,1].set_title('Bar chart')
axs[0,1].legend()
axs[1,0].scatter(x,y2,color='red',label='Scatter Points')
axs[1,0].set_title('Scatter Plot')
axs[1,0].legend()
axs[1,1].pie(y1,labels=x,autopct='%1.1f%%',colors=['blue','red','green','purple','orange'])
axs[1,1].set_title('Pie Chart')
plt.tight_layout()
plt.show()

# %% [markdown]
# 13. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# linestyle -, width .5. and color blue.
# Date,Close
# 03-10-16,772.559998
# 04-10-16,776.429993
# 05-10-16,776.469971
# 06-10-16,776.859985
# 07-10-16,775.080017

# %%
import pandas as pd
df = pd.read_csv("Dates.csv")
dates = df["Date"]
closing_value = df["Close"]
plt.plot(dates,closing_value,marker='o',linestyle='-',color='red',label='Closing Value')
plt.grid(True,linestyle='-',linewidth=0.5,color='blue')
plt.xlabel('Date')
plt.ylabel('closing Value')
plt.title('Line Chart')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# 14. Write a Python program to display the grid and draw line charts of the closing value of
# Alphabet Inc. between October 3, 2016 to October 7, 2016. Customized the grid lines with
# rendering with a larger grid (major grid) and a smaller grid (minor grid).Turn on the grid but turn off ticks.

# %%
import pandas as pd
df = pd.read_csv("Dates.csv")
dates = df["Date"]
closing_values = df["Close"]
plt.plot(dates,closing_values,marker='o',linestyle='-',color='red',label='Closing Value')
plt.minorticks_on()
plt.grid(True,which='major',linestyle='-',linewidth=0.8,color='blue')
plt.grid(True,which='minor',linestyle='--',linewidth=0.5,color='green')
plt.tick_params(axis='both',which='both',bottom=False,top=False,left=False,right=False)
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.title('Closing Values')
plt.legend()
plt.show()

# %% [markdown]
# 15. Write a Python program to create multiple plots

# %%
import numpy as np
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)
y4 = np.exp(-x)


fig, axes = plt.subplots(2, 2, figsize=(10, 8))

axes[0, 0].plot(x, y1, 'r') 
axes[0, 0].set_title("Sine Wave")

axes[0, 1].plot(x, y2, 'g')  
axes[0, 1].set_title("Cosine Wave")

axes[1, 0].plot(x, y3, 'b')  
axes[1, 0].set_ylim(-10, 10)  
axes[1, 0].set_title("Tangent Wave")

axes[1, 1].plot(x, y4, 'm')  
axes[1, 1].set_title("Exponential Decay")

plt.tight_layout()
plt.show()
